# %%
import algorithm
import math
# Out:
# numpy version 1.16.2

# %%
args = {
    "pop_size": 100,
    "crossover": 0.05,
    "mutation": 0.05
}

# %%
country = algorithm.Field(num_cities=100)

# %%
country.evolve()
